# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
season = pd.read_csv('../Basketball Reference Stat Scraper/player_stats/1980_player_stats.csv',index_col=0)
for i in range(1981,2022):
    season = season.append(pd.read_csv(f'../Basketball Reference Stat Scraper/player_stats/{i}_player_stats.csv',index_col=0))

# %%
playoffs = pd.read_csv('../Basketball Reference Stat Scraper/playoffs/1980_player_playoff_stats.csv',index_col=0)

for i in range(1981,2022):
    playoffs = playoffs.append(pd.read_csv(f'../Basketball Reference Stat Scraper/playoffs/{i}_player_playoff_stats.csv',index_col=0))

# %%
season
# Out:
#                    Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 0    Kareem Abdul-Jabbar*   C   32  LAL  82   0  38.3  10.2  16.9  0.604  ...
# 1           Tom Abernethy  PF   25  GSW  67   0  18.2   2.3   4.7  0.481  ...
# 2             Alvan Adams   C   25  PHO  75   0  28.9   6.2  11.7  0.531  ...
# 3         Tiny Archibald*  PG   31  BOS  80  80  35.8   4.8   9.9  0.482  ...
# 4           Dennis Awtrey   C   31  CHI  26   0  21.5   1.0   2.3  0.450  ...
# ..                    ...  ..  ...  ...  ..  ..   ...   ...   ...    ...  ...
# 456     Robert Woodard II  SF   21  SAC  13   0   3.5   0.6   1.5  0.400  ...
# 457        Thaddeus Young  PF   32  CHI  68  23  24.3   5.4   9.7  0.559  ...
# 458            Trae Young  PG   22  ATL  63  63  33.7   7.7  17.7  0.438  ...
# 459           Cody Zeller   C   28  CHO  48  21  20.9   3.8   6.8  0.559  ...
# 460           Ivica Zubac   C   23  LAC  72  33  22.3   3.6   5.5  0.652  ...
#
# ...

# %%
play = playoffs[playoffs['Player' ] == 'Rick Barry*']
d = season[season['Player'] == 'Rick Barry*']

# %%
plt.plot('Year','MP',data=d)
plt.plot('Year','MP',data=play)

# %%
for i in ['MP',  'PTS', 'PER', 'TS%','3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%','USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP',]:
    plt.legend(['Reg Season','Playoffs'])
    plt.title(i)

    for j in list(playoffs[playoffs['Year'] > 2019].Player.unique()):
        # print(j)



        plt.plot('Year',i,data=season[season['Player'] == j])
        plt.plot('Year',i,data=playoffs[playoffs['Player'] == j])




    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [98], in <module>
#       3 plt.title(i)
#       5 for j in list(playoffs[playoffs['Year'] > 2019].Player.unique()):
#       6     # print(j)
# ---> 10     plt.plot('Year',i,data=season[season['Player'] == j])
#      11     plt.plot('Year',i,data=playoffs[playoffs['Player'] == j])
#      16 plt.show()
#
# File ~/Dropbox/NBA/venv/lib/python3.9/site-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
for j in list(playoffs.Player.unique()):
    s = playoffs[playoffs['Player'] == j]
    # print(j)



    # plt.plot('Year',i,data=season[season['Player'] == j])
    plt.plot('Year','MP',data=s)
plt.show()

# %%
# Out:
# /var/folders/0p/ttyhqytj0zxf3tq1njp37rqw0000gn/T/ipykernel_98925/3069027258.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   s = playoffs[season['Player'] == j]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [93], in <module>
# ----> 1 s = playoffs[season['Player'] == j]
#
# File ~/Dropbox/NBA/venv/lib/python3.9/site-packages/pandas/core/frame.py:3449, in DataFrame.__getitem__(self, key)
#    3447 # Do we have a (boolean) 1d indexer?
#    3448 if com.is_bool_indexer(key):
# -> 3449     return self._getitem_bool_array(key)
#    3451 # We are left with two options: a single key, and a collection of keys,
#    3452 # We interpret tuples as collections only for non-MultiIndex
#    3453 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# ...
