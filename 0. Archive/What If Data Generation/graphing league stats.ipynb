# %%
import pandas as pd
import numpy as np
from plotly import express as px
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('../Basketball Reference Stat Scraper/team_stats/all.csv',index_col=0)
df
# Out:
#                      Team   G     MP    FG   FGA    FG%    3P   3PA    3P%  \
# 0         Boston Celtics*  82  242.4  41.9  89.2  0.470   0.9   3.2  0.286
# 1     Los Angeles Lakers*  82  242.4  45.4  96.6  0.470   1.0   3.3  0.285
# 2     Philadelphia 76ers*  82  242.1  42.0  92.2  0.455   0.9   3.4  0.271
# 3    Seattle SuperSonics*  82  241.8  41.6  90.5  0.459   0.7   2.9  0.246
# 4           Phoenix Suns*  82  240.9  43.5  91.2  0.476   1.2   3.6  0.337
# ..                    ...  ..    ...   ...   ...    ...   ...   ...    ...
# 26  Oklahoma City Thunder  75  241.7  38.2  89.3  0.428  12.1  37.6  0.321
# 27        Houston Rockets  76  241.0  39.1  86.0  0.455  13.4  38.5  0.349
# 28        Detroit Pistons  76  241.3  38.1  88.7  0.430  11.1  34.2  0.326
# 29          Orlando Magic  76  241.3  38.2  88.2  0.434  12.0  36.4  0.329
# 30    League Average 2022  76  241.4  40.5  88.1  0.460  12.4  35.2  0.352
#
# ...

# %%
league = df.loc[df['Team'].str.contains('League'),:]
league
# Out:
#                    Team   G     MP    FG   FGA    FG%    3P   3PA    3P%  \
# 22  League Average 1980  82  241.8  43.6  90.6  0.481   0.8   2.8  0.280
# 23  League Average 1981  82  241.4  43.0  88.4  0.486   0.5   2.0  0.245
# 23  League Average 1982  82  241.6  43.3  88.2  0.491   0.6   2.3  0.262
# 23  League Average 1983  82  241.3  43.5  89.7  0.485   0.5   2.3  0.238
# 23  League Average 1984  82  242.0  43.5  88.4  0.492   0.6   2.4  0.250
# 23  League Average 1985  82  241.4  43.8  89.1  0.491   0.9   3.1  0.282
# 23  League Average 1986  82  241.6  43.2  88.6  0.487   0.9   3.3  0.282
# 23  League Average 1987  82  241.6  42.6  88.8  0.480   1.4   4.7  0.301
# 23  League Average 1988  82  241.3  42.1  87.7  0.480   1.6   5.0  0.316
# 25  League Average 1989  82  241.5  42.5  89.0  0.477   2.1   6.6  0.323
# 27  League Average 1990  82  241.5  41.5  87.2  0.476   2.2   6.6  0.331
# 27  League Average 1991  82  241.8  41.4  87.2  0.474   2.3   7.1  0.320
# ...

# %%
plt.plot('Year','ORtg',data=league)
# plt.plot('Year','DRtg',data=league)

# league.plot('Year','ORtg',)
# league.plot('Year','DRtg',)

# %%
stats = [ 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA',
       '2P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
       'TOV', 'PF', 'PTS', 'Age', 'ORtg', 'Pace', 'FTr', '3PAr', 'TS%', 'Year']

for stat in stats:
       plt.plot('Year',stat,data=league,)
       plt.title(stat)
       plt.grid(True)
       plt.show()

# %%
league.plot('Year','DRtg',)

# %%
for stat in stats:



       team = df.loc[df['Team'].str.contains('Atlanta'),stat,]
       years = df.loc[df['Team'].str.contains('Atlanta'),'Year']
       league = df.loc[df['Team'].str.contains('League'),stat]
       stats_vs_league = team.values - league.values
       # print(len(team))
       # print(len(league))
       # print(stats_vs_league)
       # break
       #
       plt.plot(years,stats_vs_league)
       plt.title(stat)
       plt.grid(True)
       plt.show()
