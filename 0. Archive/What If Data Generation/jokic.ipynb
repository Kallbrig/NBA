# %%
import pandas as pd
import matplotlib.pyplot as plt
from  datetime import datetime
import numpy as np

# %%
players = pd.read_csv('../Data/Players With Award Data/players_with_award_voting.csv',index_col=0)
teams = pd.read_csv('../Basketball Reference Stat Scraper/team_stats/pre_1980/all_pre_1980.csv',index_col=0)

test_set = pd.read_csv(
    f'/Users/chaseallbright/Dropbox/NBA/Data/Test Sets/{datetime.now().strftime("%Y")}/{datetime.now().strftime("%Y%m%d")}_player_stats.csv',
    index_col=0)
players = players.append(test_set)

# %%
players.loc[players['Player'].str.contains('Chris Paul'),:]
# Out:
#            Player Pos   Age   Tm     G    GS    MP   FG   FGA    FG%  ...  \
# 9986   Chris Paul  PG  20.0  NOK  78.0  78.0  36.0  5.2  12.1  0.430  ...
# 10797  Chris Paul  PG  21.0  NOK  64.0  64.0  36.8  6.0  13.6  0.437  ...
# 10897  Chris Paul  PG  22.0  NOH  80.0  80.0  37.6  7.9  16.1  0.488  ...
# 11614  Chris Paul  PG  23.0  NOH  78.0  78.0  38.5  8.1  16.1  0.503  ...
# 12082  Chris Paul  PG  24.0  NOH  45.0  45.0  38.0  7.0  14.2  0.493  ...
# 12231  Chris Paul  PG  25.0  NOH  80.0  80.0  36.0  5.4  11.6  0.463  ...
# 12665  Chris Paul  PG  26.0  LAC  60.0  60.0  36.4  7.1  14.8  0.478  ...
# 13539  Chris Paul  PG  27.0  LAC  70.0  70.0  33.4  5.9  12.2  0.481  ...
# 14020  Chris Paul  PG  28.0  LAC  62.0  62.0  35.0  6.5  14.0  0.467  ...
# 14518  Chris Paul  PG  29.0  LAC  82.0  82.0  34.8  6.9  14.3  0.485  ...
# 14686  Chris Paul  PG  30.0  LAC  74.0  74.0  32.7  7.0  15.1  0.462  ...
# 15071  Chris Paul  PG  31.0  LAC  61.0  61.0  31.5  6.1  12.9  0.476  ...
# ...

# %%
teams.loc[(teams['Team'].str.contains('Nuggets')) & (teams['Year'] > 2000),:]
# Out:
#                Team     G     MP    FG   FGA    FG%    3P   3PA    3P%    2P  \
# 18   Denver Nuggets  82.0  241.2  37.6  84.3  0.446   5.1  14.2  0.356  32.5
# 25   Denver Nuggets  82.0  241.5  36.6  79.8  0.459   5.2  14.3  0.361  31.5
# 27   Denver Nuggets  82.0  240.6  32.9  74.2  0.443   5.1  13.8  0.370  27.8
# 10  Denver Nuggets*  82.0  240.6  36.8  81.2  0.453   4.6  12.9  0.356  32.2
# 8   Denver Nuggets*  82.0  240.9  36.0  80.6  0.447   5.6  16.4  0.345  30.3
# 10  Denver Nuggets*  82.0  243.0  37.4  82.5  0.454   6.5  18.0  0.358  31.0
# 9   Denver Nuggets*  82.0  241.2  39.7  86.4  0.460   6.8  19.1  0.353  33.0
# 10  Denver Nuggets*  82.0  242.1  40.7  89.1  0.457   7.6  20.9  0.363  33.1
# 5   Denver Nuggets*  82.0  240.6  36.2  82.2  0.440   7.3  20.0  0.366  28.8
# 5   Denver Nuggets*  82.0  241.2  37.7  82.5  0.456   6.4  18.3  0.349  31.3
# 8   Denver Nuggets*  82.0  240.3  38.5  83.9  0.459   7.0  20.4  0.344  31.4
# ...

# %%
players.loc[(players.Player == 'Nikola Jokić'),['Year','Tm_ORtg','Tm_DRtg']]
# Out:
#        Year  Tm_ORtg  Tm_DRtg
# 14635  2016    113.2    112.7
# 15163  2017    112.5    111.0
# 15602  2018    113.0    108.9
# 16454  2019      NaN      NaN
# 16729  2020      NaN      NaN
# 17638  2021      NaN      NaN
# 241    2022      NaN      NaN

# %%
a = players.columns.to_list()

# %%
df_l = []
for i in range(1980,2023):
    df_l.append(pd.read_csv(f'../Basketball Reference Stat Scraper/player_stats/{i}_player_stats.csv',index_col=0))
df = pd.concat(df_l)

df.Player = df.Player.str.strip('*')
df
# Out:
#                   Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 0    Kareem Abdul-Jabbar   C   32  LAL  82   0  38.3  10.2  16.9  0.604  ...
# 1          Tom Abernethy  PF   25  GSW  67   0  18.2   2.3   4.7  0.481  ...
# 2            Alvan Adams   C   25  PHO  75   0  28.9   6.2  11.7  0.531  ...
# 3         Tiny Archibald  PG   31  BOS  80  80  35.8   4.8   9.9  0.482  ...
# 4          Dennis Awtrey   C   31  CHI  26   0  21.5   1.0   2.3  0.450  ...
# ..                   ...  ..  ...  ...  ..  ..   ...   ...   ...    ...  ...
# 509         Moses Wright  PF   23  LAC   1   0   1.0   0.0   0.0  0.000  ...
# 510           Trae Young  PG   23  ATL  55  55  34.5   9.4  20.5  0.457  ...
# 511       Omer Yurtseven   C   23  MIA  44  10  13.9   2.6   4.9  0.540  ...
# 512          Cody Zeller   C   29  POR  27   0  13.1   1.9   3.3  0.567  ...
# 513          Ivica Zubac   C   24  LAC  57  57  24.3   3.8   5.8  0.650  ...
#
# ...

# %%
# for i in (df.select_dtypes(include=[np.number])).columns:
#     # df.loc[(df['Player'] == 'Nikola Jokić'),['Year',i]].plot()
#     plt.plot('Age',i,data=df.loc[(df['Player'] == 'Nikola Jokić'),['Age',i]])
#     plt.plot('Age',i,data=df.loc[(df['Player'] == 'Chris Paul'),['Age',i]])
#     # plt.plot('Age',i,data=df.loc[(df['Player'] == 'Larry Bird'),['Age',i]])
#     plt.title(i)
#     plt.legend(['Jokic','Paul','Bird'])
#     plt.tight_layout()
#     plt.grid(True)
#     plt.show()

# %%
teams.loc[(teams.Year.isin(df.loc[(df['Player'] == 'Nikola Jokić'),'Year'])) & teams.Team.str.contains('Denver'),:]
# Out:
#                Team     G     MP    FG   FGA    FG%    3P   3PA    3P%    2P  \
# 20   Denver Nuggets  82.0  241.8  37.7  85.4  0.442   8.0  23.7  0.338  29.7
# 17   Denver Nuggets  82.0  240.9  41.2  87.7  0.469  10.6  28.8  0.368  30.6
# 13   Denver Nuggets  82.0  242.4  40.7  86.6  0.470  11.5  30.9  0.371  29.2
# 3   Denver Nuggets*  82.0  240.6  41.9  90.0  0.466  11.0  31.4  0.351  30.9
# 5   Denver Nuggets*  73.0  243.1  42.0  88.9  0.473  11.0  30.6  0.359  31.1
# 4   Denver Nuggets*  72.0  242.8  43.3  89.2  0.485  12.9  34.2  0.377  30.4
# 8    Denver Nuggets  76.0  241.3  41.3  86.2  0.479  12.8  36.1  0.354  28.6
#
#     ...   SOS   SRS   ORtg   DRtg  NRtg  Pace    FTr   3PAr    TS%    Year
# 20  ...  0.29 -2.81  105.6  108.9  -3.3  95.7  0.282  0.277  0.531  2016.0
# 17  ...  0.19  0.70  113.2  112.7   0.5  98.3  0.276  0.329  0.568  2017.0
# 13  ...  0.09  1.57  112.5  111.0   1.5  96.8  0.258  0.357  0.570  2018.0
# ...

# %%
teams.loc[(teams.Year.isin(df.loc[(df['Player'] == 'Chris Paul'),'Year'])) & teams.Team.str.contains('Suns'),:]
# Out:
#              Team     G     MP    FG   FGA    FG%    3P   3PA    3P%    2P  \
# 3   Phoenix Suns*  82.0  243.4  39.5  87.1  0.454   6.3  17.4  0.363  33.3
# 1   Phoenix Suns*  82.0  242.7  39.5  86.4  0.457   6.1  16.9  0.363  33.3
# 6   Phoenix Suns*  82.0  241.2  41.1  90.0  0.456   5.7  16.2  0.353  35.4
# 12   Phoenix Suns  82.0  240.9  40.0  85.7  0.467   7.6  19.9  0.383  32.3
# 4   Phoenix Suns*  82.0  240.6  39.5  87.4  0.452   6.8  19.3  0.355  32.6
# 16   Phoenix Suns  82.0  244.0  40.4  85.6  0.472   7.1  19.5  0.367  33.2
# 17   Phoenix Suns  66.0  240.0  38.0  83.5  0.455   6.0  17.1  0.352  31.9
# 26   Phoenix Suns  82.0  241.5  38.8  82.6  0.470   6.9  17.9  0.388  31.9
# 11   Phoenix Suns  82.0  240.9  38.0  83.4  0.456   6.8  19.9  0.341  31.2
# 16   Phoenix Suns  82.0  242.4  38.4  85.0  0.452   7.7  21.9  0.352  30.7
# 26   Phoenix Suns  82.0  240.3  37.2  85.6  0.435   9.0  25.8  0.348  28.2
# ...
