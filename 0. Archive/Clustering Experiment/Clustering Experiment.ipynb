# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split as tts

from tabulate import tabulate

from sklearn.neighbors import KNeighborsClassifier

pd.set_option('max_columns', None)

# %%
df = pd.read_csv('../Data/Combined Player and Team Data/improved_combined_player_and_team_data.csv',index_col='Unnamed: 0')
df = df.dropna()


df_2018 = df[df.Year == 2000]


df_train = df.drop(df_2018.index)



df_train = df_train.drop(columns=['Player','Pos','Tm'])

df_test_plug_in = df_2018.drop(columns=['Player','Pos','Tm'])

df.columns

df = df[['PTS','TRB','AST']]

# %%
kmeans = KMeans(random_state=0).fit(df)


# df[X.pred_pos == 4].Pos
# df

# %%
a = kmeans.predict(df_test_plug_in)

kmeans.cluster_centers_

# df_2018
# Out:
# array([[ 2.65532194e+01,  6.68679369e+01,  7.55124836e+00,
#          1.78719448e+01,  2.53620237e+00,  5.70394218e+00,
#          4.43611695e-01,  4.19448095e-01,  1.21478318e+00,
#          2.53024967e-01,  2.11399474e+00,  4.48784494e+00,
#          4.67335742e-01,  4.78189225e-01,  1.22161629e+00,
#          1.63416557e+00,  7.39639290e-01,  8.34625493e-01,
#          1.99172142e+00,  2.82536137e+00,  1.54441524e+00,
#          5.99014455e-01,  3.07752957e-01,  1.02923784e+00,
#          1.82785808e+00,  6.71445466e+00,  1.64257556e-02,
#          2.00163732e+03,  2.69222076e+01,  4.04349540e+01,
#          3.95446781e+01,  4.03587385e+01,  3.96208936e+01,
#          1.40111695e-01, -2.64191853e-02,  1.13672799e-01,
#          1.06737779e+02,  1.06588042e+02,  1.49737188e-01,
#          9.44683311e+01,  3.06051248e-01,  1.83948095e-01,
#          5.35672142e-01,  4.92124179e-01,  1.37595269e+01,
#          2.85729961e+01,  2.31337714e-01,  4.93128121e-01,
# ...

# %%
df_2018['pred'] = a
# Out:
# /var/folders/0p/ttyhqytj0zxf3tq1njp37rqw0000gn/T/ipykernel_1273/689287644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['pred'] = a

# %%
pd.set_option('display.max_rows', None)
df_2018[['Player','Tm','Pos','MP','PTS','eFG%','AST','TRB','STL','BLK','Tm_W','Tm_L']].loc[df_2018['pred'] == 0].to_csv('zero.csv',index = False)
df_2018[['Player','Tm','Pos','MP','PTS','eFG%','AST','TRB','STL','BLK','Tm_W','Tm_L']].loc[df_2018['pred'] == 1].to_csv('one.csv',index = False)
df_2018[['Player','Tm','Pos','MP','PTS','eFG%','AST','TRB','STL','BLK','Tm_W','Tm_L']].loc[df_2018['pred'] == 2].to_csv('two.csv',index = False)
df_2018[['Player','Tm','Pos','MP','PTS','eFG%','AST','TRB','STL','BLK','Tm_W','Tm_L']].loc[df_2018['pred'] == 3].to_csv('three.csv',index = False)
df_2018[['Player','Tm','Pos','MP','PTS','eFG%','AST','TRB','STL','BLK','Tm_W','Tm_L']].loc[df_2018['pred'] == 4].to_csv('four.csv',index = False)

# tabulate(zero, headers=zero.columns,showindex=False)

# %%
df_2018.keys()
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'STAR', 'Year',
#        'Tm_AGE', 'Tm_W', 'Tm_L', 'Tm_PW', 'Tm_PL', 'Tm_MOV', 'Tm_SOS',
#        'Tm_SRS', 'Tm_ORtg', 'Tm_DRtg', 'Tm_NRtg', 'Tm_PACE', 'Tm_FTr',
#        'Tm_3PAr', 'Tm_TS%', 'Tm_eFG%', 'Tm_TOV%', 'Tm_ORB%', 'Tm_FT/FGA',
#        'Tm_Op_eFG%', 'Tm_Op_TOV%', 'Tm_DRB%', 'Tm_Op_FT/FGA', 'Win%'],
#       dtype='object')

# %%
df_2018[['Player','Tm','Pos','MP','PTS','eFG%','AST','TRB','STL','BLK','Tm_W','Tm_L']].loc[df_2018['pred'] == 0].describe().mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pred'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_2018[['Player','Tm','Pos','MP','PTS','eFG%','AST','TRB','STL','BLK','Tm_W','Tm_L']].loc[df_2018['pred'] == 1].describe().mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pred'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_2018[['Player','Tm','Pos','MP','PTS','eFG%','AST','TRB','STL','BLK','Tm_W','Tm_L']].loc[df_2018['pred'] == 2].describe().mean()
df_2018[['Player','Tm','Pos','MP','PTS','eFG%','AST','TRB','STL','BLK','Tm_W','Tm_L']].loc[df_2018['pred'] == 3].describe().mean()
# df_2018
# Out:
# MP      17.820768
# PTS     10.373265
# eFG%     6.431873
# AST      7.493691
# TRB      9.177950
# STL      6.526370
# BLK      6.332888
# Tm_W    41.387426
# Tm_L    34.198650
# dtype: float64

# %%
df_2018[['PTS','TRB','AST','eFG%','FG%','BLK','Tm_ORtg','Win%']].loc[df_2018['pred'] == 4].mean()
# Out:
# /var/folders/0p/ttyhqytj0zxf3tq1njp37rqw0000gn/T/ipykernel_65522/977543916.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_2018.loc[df_2018['pred'] == 4].mean()
# Age               26.117647
# G                 73.686275
# GS                66.215686
# MP                31.733333
# FG                 5.258824
# FGA               11.960784
# FG%                0.439902
# 3P                 0.662745
# 3PA                1.905882
# 3P%                0.262431
# 2P                 4.598039
# 2PA               10.052941
# 2P%                0.455745
# eFG%               0.468490
# FT                 2.841176
# FTA                3.743137
# FT%                0.754176
# ORB                1.539216
# DRB                3.756863
# TRB                5.296078
# AST                3.235294
# ...

# %%
for i in range(0,5):

    df_2018[['PTS','TRB','AST','eFG%','FG%','BLK','Tm_ORtg','Win%']].loc[df_2018['pred'] == i].mean().round(3).to_csv(f'{i}.csv')

# %%
# df_2018.loc[df_2018['pred'] == 4]

# %%
df[(df['Player'] == 'Magic Johnson') & (df['Year'] == 1990)]
# Out:
#              Player Pos   Age   Tm     G    GS    MP   FG   FGA   FG%   3P  \
# 3255  Magic Johnson  PG  30.0  LAL  79.0  79.0  37.2  6.9  14.4  0.48  1.3
#
#       3PA    3P%   2P   2PA   2P%   eFG%   FT  FTA   FT%  ORB  DRB  TRB   AST  \
# 3255  3.5  0.384  5.6  10.9  0.51  0.526  7.2  8.1  0.89  1.6  5.0  6.6  11.5
#
#       STL  BLK  TOV   PF   PTS  STAR  Year  Tm_AGE  Tm_W  Tm_L  Tm_PW  Tm_PL  \
# 3255  1.7  0.4  3.7  2.1  22.3  True  1990    28.4  58.0  24.0   59.0   23.0
#
#       Tm_MOV  Tm_SOS  Tm_SRS  Tm_ORtg  Tm_DRtg  Tm_NRtg  Tm_PACE  Tm_FTr  \
# 3255    6.74   -0.01    6.73    112.1    105.0      7.1     94.1   0.327
#
#       Tm_3PAr  Tm_TS%  Tm_eFG%  Tm_TOV%  Tm_ORB%  Tm_FT/FGA  Tm_Op_eFG%  \
# 3255    0.108   0.551      0.5     13.2     33.0      0.261       0.474
#
#       Tm_Op_TOV%  Tm_DRB%  Tm_Op_FT/FGA   Win%
# 3255        12.8     68.3         0.176  0.707

# %%
df[df['Year'] == 1990].describe()
# Out:
#               Age           G          GS          MP          FG         FGA  \
# count  266.000000  266.000000  266.000000  266.000000  266.000000  266.000000
# mean    26.860902   64.586466   32.981203   22.618045    3.897744    8.253383
# std      3.533053   21.178532   31.800374   10.321956    2.570998    5.007067
# min     20.000000    1.000000    0.000000    2.100000    0.000000    0.600000
# 25%     24.000000   54.250000    2.000000   13.800000    1.725000    3.900000
# 50%     26.000000   74.000000   21.500000   22.900000    3.300000    7.000000
# 75%     29.000000   81.000000   67.750000   32.250000    5.700000   11.900000
# max     39.000000   82.000000   82.000000   39.500000   12.600000   24.000000
#
#              FG%          3P         3PA         3P%          2P         2PA  \
# count  266.00000  266.000000  266.000000  266.000000  266.000000  266.000000
# mean     0.45391    0.226692    0.702632    0.228278    3.669549    7.549624
# ...
