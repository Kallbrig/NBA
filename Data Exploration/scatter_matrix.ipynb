# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../Data/Players With Award Data/complete_players_with_award_voting.csv',index_col='Unnamed: 0')

# %%
df.columns
# scatter_matrix(df)
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'STAR', 'Year',
#        'Tm_AGE', 'Tm_W', 'Tm_L', 'Tm_PW', 'Tm_PL', 'Tm_MOV', 'Tm_SOS',
#        'Tm_SRS', 'Tm_ORtg', 'Tm_DRtg', 'Tm_NRtg', 'Tm_PACE', 'Tm_FTr',
#        'Tm_3PAr', 'Tm_TS%', 'Tm_eFG%', 'Tm_TOV%', 'Tm_ORB%', 'Tm_FT/FGA',
#        'Tm_Op_eFG%', 'Tm_Op_TOV%', 'Tm_DRB%', 'Tm_Op_FT/FGA', 'Win%',
#        'DPOY_Rank', 'DPOY_First', 'DPOY_Pts Won', 'DPOY_Pts Max', 'DPOY_Share',
#        'DPOY', 'MIP_Rank', 'MIP_First', 'MIP_Pts Won', 'MIP_Pts Max',
#        'MIP_Share', 'MIP', 'MVP_Rank', 'MVP_First', 'MVP_Pts Won',
#        'MVP_Pts Max', 'MVP_Share', 'MVP', 'ROTY_Rank', 'ROTY_First',
#        'ROTY_Pts Won', 'ROTY_Pts Max', 'ROTY_Share', 'ROTY', 'SMOTY_Rank',
#        'SMOTY_First', 'SMOTY_Pts Won', 'SMOTY_Pts Max', 'SMOTY_Share',
#        'SMOTY'],
# ...

# %%
attributes = ['TRB', 'AST', 'STL', 'BLK', 'TOV', 'PTS','MVP_Share', ]
attributes = ['AST','TOV','PTS']

df[attributes].corr()
# Out:
#           AST       TOV       PTS
# AST  1.000000  0.748774  0.613419
# TOV  0.748774  1.000000  0.843376
# PTS  0.613419  0.843376  1.000000

# %%
scatter_matrix(df[attributes],figsize=(25,25))

plt.savefig('e.png')

# %%
mvp = df[['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'STAR', 'Year',
       'Tm_AGE', 'Tm_W', 'Tm_L', 'Tm_PW', 'Tm_PL', 'Tm_MOV', 'Tm_SOS',
       'Tm_SRS', 'Tm_ORtg', 'Tm_DRtg', 'Tm_NRtg', 'Tm_PACE', 'Tm_FTr',
       'Tm_3PAr', 'Tm_TS%', 'Tm_eFG%', 'Win%','MVP']]

# %%
df[df['MVP'] == True].sort_values('Year').reset_index(drop=True).Year.tolist()
# Out:
# [1986,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018]

# %%
df[(df['Year'] == 1980) & (df['MVP_Share'] != 0)]
# Out:
# Empty DataFrame
# Columns: [Player, Pos, Age, Tm, G, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS, STAR, Year, Tm_AGE, Tm_W, Tm_L, Tm_PW, Tm_PL, Tm_MOV, Tm_SOS, Tm_SRS, Tm_ORtg, Tm_DRtg, Tm_NRtg, Tm_PACE, Tm_FTr, Tm_3PAr, Tm_TS%, Tm_eFG%, Tm_TOV%, Tm_ORB%, Tm_FT/FGA, Tm_Op_eFG%, Tm_Op_TOV%, Tm_DRB%, Tm_Op_FT/FGA, Win%, DPOY_Rank, DPOY_First, DPOY_Pts Won, DPOY_Pts Max, DPOY_Share, DPOY, MIP_Rank, MIP_First, MIP_Pts Won, MIP_Pts Max, MIP_Share, MIP, MVP_Rank, MVP_First, MVP_Pts Won, MVP_Pts Max, MVP_Share, MVP, ROTY_Rank, ROTY_First, ROTY_Pts Won, ROTY_Pts Max, ROTY_Share, ROTY, SMOTY_Rank, SMOTY_First, SMOTY_Pts Won, SMOTY_Pts Max, SMOTY_Share, SMOTY]
# Index: []
#
# [0 rows x 85 columns]
